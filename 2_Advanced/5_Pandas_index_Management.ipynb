# %%
#Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data
dataset= load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name ='job_index'

# %%
df.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# 3                       San Antonio, TX   via Diversity.com         Full-time
# 4                        Washington, DC  via Clearance Jobs         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# job_index
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
# 2                       False               Germany 2023-10-10 13:14:55
# 3                       False  Texas, United States 2023-07-04 13:01:41
# 4                       False                 Sudan 2023-08-07 14:29:36
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 1                          False                 False         Mexico
# 2                          False                 False        Germany
# 3                           True                 False  United States
# 4                          False                 False          Sudan
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                None              NaN              NaN
# 1                None              NaN              NaN
# 2                None              NaN              NaN
# 3                None              NaN              NaN
# 4                None              NaN              NaN
#
#                            company_name  \
# job_index
# 0                  Boehringer Ingelheim
# 1            Hewlett Packard Enterprise
# 2              ALPHA Augmented Services
# 3          Southwest Research Institute
# 4                       Kristina Daniel
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # reset_index()

# %%
df_nepal = df[df['job_country'] == 'Nepal']

# %%
df_nepal.reset_index(inplace=True)
df_nepal
# Out:
#      job_index    job_title_short  \
# 0         1746      Data Engineer
# 1         2925  Software Engineer
# 2        21167       Data Analyst
# 3        24730       Data Analyst
# 4        26074       Data Analyst
# ..         ...                ...
# 265     775260      Data Engineer
# 266     776749      Data Engineer
# 267     779134      Data Engineer
# 268     779603  Software Engineer
# 269     781229      Data Engineer
#
#                                              job_title      job_location  \
# 0                                     Data QA Engineer   Lalitpur, Nepal
# 1                                         SQL Engineer   Lalitpur, Nepal
# 2    U-Report Data Analyst Consultant, UNICEF Regio...             Nepal
# 3                               Data Analytics Manager   Lalitpur, Nepal
# 4                    Data Reporting Analyst – Power BI          Anywhere
# ..                                                 ...               ...
# 265                                      Data Engineer  Kathmandu, Nepal
# 266                                      Data Engineer  Kathmandu, Nepal
# 267                                      Data Engineer  Kathmandu, Nepal
# 268                        Sr Software Engineer (.Net)  Kathmandu, Nepal
# 269                                      Data Engineer  Kathmandu, Nepal
#
#                             job_via job_schedule_type  job_work_from_home  \
# 0                       via Merojob         Full-time               False
# 1                       via Merojob         Full-time               False
# 2             via UNJoblink Careers        Contractor               False
# 3                       via Merojob         Full-time               False
# 4                via LinkedIn Nepal         Full-time                True
# ..                              ...               ...                 ...
# 265              via LinkedIn Nepal         Full-time               False
# 266              via LinkedIn Nepal         Full-time               False
# 267              via LinkedIn Nepal         Full-time               False
# 268  via SmartRecruiters Job Search         Full-time               False
# 269                   via Vrit Jobs         Full-time               False
#
#     search_location     job_posted_date  job_no_degree_mention  \
# 0             Nepal 2023-08-09 14:04:23                   True
# 1             Nepal 2023-03-24 14:26:30                   True
# 2             Nepal 2023-07-17 14:09:19                  False
# 3             Nepal 2023-09-01 14:01:47                   True
# 4             Nepal 2023-04-05 13:29:48                  False
# ..              ...                 ...                    ...
# 265           Nepal 2023-05-29 01:15:23                  False
# 266           Nepal 2023-01-23 05:57:15                  False
# 267           Nepal 2023-01-22 06:13:07                  False
# 268           Nepal 2023-01-12 05:42:44                  False
# 269           Nepal 2023-01-18 06:42:07                   True
#
#      job_health_insurance job_country salary_rate  salary_year_avg  \
# 0                   False       Nepal        None              NaN
# 1                   False       Nepal        None              NaN
# 2                   False       Nepal        None              NaN
# 3                   False       Nepal        None              NaN
# 4                   False       Nepal        None              NaN
# ..                    ...         ...         ...              ...
# 265                 False       Nepal        None              NaN
# 266                 False       Nepal        None              NaN
# 267                 False       Nepal        None              NaN
# 268                 False       Nepal        None              NaN
# 269                 False       Nepal        None              NaN
#
#      salary_hour_avg                             company_name  \
# 0                NaN                      Cedar Gate Services
# 1                NaN                    Impetus Incorporation
# 2                NaN  United Nations Children's Fund (UNICEF)
# 3                NaN                      Cedar Gate Services
# 4                NaN        Linkbridge Technologies Pvt. Ltd.
# ..               ...                                      ...
# 265              NaN                 Codavatar Tech Pvt. Ltd.
# 266              NaN                       Reputed IT Company
# 267              NaN                          Reputed Company
# 268              NaN                                   Verisk
# 269              NaN                        Audit Partnership
#
#                                             job_skills  \
# 0                                                 None
# 1                                              ['sql']
# 2          ['r', 'python', 'excel', 'tableau', 'flow']
# 3                                                 None
# 4                                  ['power bi', 'dax']
# ..                                                 ...
# 265  ['python', 'c++', 'java', 'r', 'sql', 'hadoop'...
# 266  ['sql', 't-sql', 'c#', 'python', 'vba', 'sql s...
# 267  ['sql', 't-sql', 'c#', 'python', 'vba', 'sql s...
# 268  ['c#', 'javascript', 'sql', 'postgresql', 'aws...
# 269  ['sql', 't-sql', 'c#', 'python', 'vba', 'sql s...
#
#                                        job_type_skills
# 0                                                 None
# 1                             {'programming': ['sql']}
# 2    {'analyst_tools': ['excel', 'tableau'], 'other...
# 3                                                 None
# 4               {'analyst_tools': ['power bi', 'dax']}
# ..                                                 ...
# 265  {'libraries': ['hadoop', 'gdpr'], 'programming...
# 266  {'analyst_tools': ['ssrs'], 'databases': ['sql...
# 267  {'analyst_tools': ['ssrs'], 'databases': ['sql...
# 268  {'analyst_tools': ['sharepoint'], 'cloud': ['a...
# 269  {'analyst_tools': ['ssrs'], 'databases': ['sql...
#
# [270 rows x 18 columns]

# %% [markdown]
# # set_index()

# %%
df_nepal.set_index('job_index', inplace=True)
df_nepal
# Out:
#              job_title_short  \
# job_index
# 1746           Data Engineer
# 2925       Software Engineer
# 21167           Data Analyst
# 24730           Data Analyst
# 26074           Data Analyst
# ...                      ...
# 775260         Data Engineer
# 776749         Data Engineer
# 779134         Data Engineer
# 779603     Software Engineer
# 781229         Data Engineer
#
#                                                    job_title  \
# job_index
# 1746                                        Data QA Engineer
# 2925                                            SQL Engineer
# 21167      U-Report Data Analyst Consultant, UNICEF Regio...
# 24730                                 Data Analytics Manager
# 26074                      Data Reporting Analyst – Power BI
# ...                                                      ...
# 775260                                         Data Engineer
# 776749                                         Data Engineer
# 779134                                         Data Engineer
# 779603                           Sr Software Engineer (.Net)
# 781229                                         Data Engineer
#
#                job_location                         job_via job_schedule_type  \
# job_index
# 1746        Lalitpur, Nepal                     via Merojob         Full-time
# 2925        Lalitpur, Nepal                     via Merojob         Full-time
# 21167                 Nepal           via UNJoblink Careers        Contractor
# 24730       Lalitpur, Nepal                     via Merojob         Full-time
# 26074              Anywhere              via LinkedIn Nepal         Full-time
# ...                     ...                             ...               ...
# 775260     Kathmandu, Nepal              via LinkedIn Nepal         Full-time
# 776749     Kathmandu, Nepal              via LinkedIn Nepal         Full-time
# 779134     Kathmandu, Nepal              via LinkedIn Nepal         Full-time
# 779603     Kathmandu, Nepal  via SmartRecruiters Job Search         Full-time
# 781229     Kathmandu, Nepal                   via Vrit Jobs         Full-time
#
#            job_work_from_home search_location     job_posted_date  \
# job_index
# 1746                    False           Nepal 2023-08-09 14:04:23
# 2925                    False           Nepal 2023-03-24 14:26:30
# 21167                   False           Nepal 2023-07-17 14:09:19
# 24730                   False           Nepal 2023-09-01 14:01:47
# 26074                    True           Nepal 2023-04-05 13:29:48
# ...                       ...             ...                 ...
# 775260                  False           Nepal 2023-05-29 01:15:23
# 776749                  False           Nepal 2023-01-23 05:57:15
# 779134                  False           Nepal 2023-01-22 06:13:07
# 779603                  False           Nepal 2023-01-12 05:42:44
# 781229                  False           Nepal 2023-01-18 06:42:07
#
#            job_no_degree_mention  job_health_insurance job_country  \
# job_index
# 1746                        True                 False       Nepal
# 2925                        True                 False       Nepal
# 21167                      False                 False       Nepal
# 24730                       True                 False       Nepal
# 26074                      False                 False       Nepal
# ...                          ...                   ...         ...
# 775260                     False                 False       Nepal
# 776749                     False                 False       Nepal
# 779134                     False                 False       Nepal
# 779603                     False                 False       Nepal
# 781229                      True                 False       Nepal
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 1746             None              NaN              NaN
# 2925             None              NaN              NaN
# 21167            None              NaN              NaN
# 24730            None              NaN              NaN
# 26074            None              NaN              NaN
# ...               ...              ...              ...
# 775260           None              NaN              NaN
# 776749           None              NaN              NaN
# 779134           None              NaN              NaN
# 779603           None              NaN              NaN
# 781229           None              NaN              NaN
#
#                                       company_name  \
# job_index
# 1746                           Cedar Gate Services
# 2925                         Impetus Incorporation
# 21167      United Nations Children's Fund (UNICEF)
# 24730                          Cedar Gate Services
# 26074            Linkbridge Technologies Pvt. Ltd.
# ...                                            ...
# 775260                    Codavatar Tech Pvt. Ltd.
# 776749                          Reputed IT Company
# 779134                             Reputed Company
# 779603                                      Verisk
# 781229                           Audit Partnership
#
#                                                   job_skills  \
# job_index
# 1746                                                    None
# 2925                                                 ['sql']
# 21167            ['r', 'python', 'excel', 'tableau', 'flow']
# 24730                                                   None
# 26074                                    ['power bi', 'dax']
# ...                                                      ...
# 775260     ['python', 'c++', 'java', 'r', 'sql', 'hadoop'...
# 776749     ['sql', 't-sql', 'c#', 'python', 'vba', 'sql s...
# 779134     ['sql', 't-sql', 'c#', 'python', 'vba', 'sql s...
# 779603     ['c#', 'javascript', 'sql', 'postgresql', 'aws...
# 781229     ['sql', 't-sql', 'c#', 'python', 'vba', 'sql s...
#
#                                              job_type_skills
# job_index
# 1746                                                    None
# 2925                                {'programming': ['sql']}
# 21167      {'analyst_tools': ['excel', 'tableau'], 'other...
# 24730                                                   None
# 26074                 {'analyst_tools': ['power bi', 'dax']}
# ...                                                      ...
# 775260     {'libraries': ['hadoop', 'gdpr'], 'programming...
# 776749     {'analyst_tools': ['ssrs'], 'databases': ['sql...
# 779134     {'analyst_tools': ['ssrs'], 'databases': ['sql...
# 779603     {'analyst_tools': ['sharepoint'], 'cloud': ['a...
# 781229     {'analyst_tools': ['ssrs'], 'databases': ['sql...
#
# [270 rows x 17 columns]

# %%
df_nepal.iloc[0:5, :]  # Select the first 5 rows (0 to 4) and all columns from the DataFrame
# Out:
#              job_title_short  \
# job_index
# 1746           Data Engineer
# 2925       Software Engineer
# 21167           Data Analyst
# 24730           Data Analyst
# 26074           Data Analyst
#
#                                                    job_title     job_location  \
# job_index
# 1746                                        Data QA Engineer  Lalitpur, Nepal
# 2925                                            SQL Engineer  Lalitpur, Nepal
# 21167      U-Report Data Analyst Consultant, UNICEF Regio...            Nepal
# 24730                                 Data Analytics Manager  Lalitpur, Nepal
# 26074                      Data Reporting Analyst – Power BI         Anywhere
#
#                          job_via job_schedule_type  job_work_from_home  \
# job_index
# 1746                 via Merojob         Full-time               False
# 2925                 via Merojob         Full-time               False
# 21167      via UNJoblink Careers        Contractor               False
# 24730                via Merojob         Full-time               False
# 26074         via LinkedIn Nepal         Full-time                True
#
#           search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 1746                Nepal 2023-08-09 14:04:23                   True
# 2925                Nepal 2023-03-24 14:26:30                   True
# 21167               Nepal 2023-07-17 14:09:19                  False
# 24730               Nepal 2023-09-01 14:01:47                   True
# 26074               Nepal 2023-04-05 13:29:48                  False
#
#            job_health_insurance job_country salary_rate  salary_year_avg  \
# job_index
# 1746                      False       Nepal        None              NaN
# 2925                      False       Nepal        None              NaN
# 21167                     False       Nepal        None              NaN
# 24730                     False       Nepal        None              NaN
# 26074                     False       Nepal        None              NaN
#
#            salary_hour_avg                             company_name  \
# job_index
# 1746                   NaN                      Cedar Gate Services
# 2925                   NaN                    Impetus Incorporation
# 21167                  NaN  United Nations Children's Fund (UNICEF)
# 24730                  NaN                      Cedar Gate Services
# 26074                  NaN        Linkbridge Technologies Pvt. Ltd.
#
#                                             job_skills  \
# job_index
# 1746                                              None
# 2925                                           ['sql']
# 21167      ['r', 'python', 'excel', 'tableau', 'flow']
# 24730                                             None
# 26074                              ['power bi', 'dax']
#
#                                              job_type_skills
# job_index
# 1746                                                    None
# 2925                                {'programming': ['sql']}
# 21167      {'analyst_tools': ['excel', 'tableau'], 'other...
# 24730                                                   None
# 26074                 {'analyst_tools': ['power bi', 'dax']}
